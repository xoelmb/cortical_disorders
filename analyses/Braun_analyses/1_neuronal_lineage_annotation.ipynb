# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# # Part 1: create an Excel with the annotation

# %%
# Load main dataset (Table S2)
path_to_annotation_info <- '~/ewce/AnnotationInfo.csv' # <-- PLEASE UPDATE THIS PATH
# st2: Dataframe holding the initial cluster information from Table S2.
st2 <- openxlsx::read.xlsx('./science.adf1226_table_s2.xlsx')
# remove not valid clusters
st2 <- subset(st2, `ClusterID.(PoolClean)` != '--') %>%
    mutate(`ClusterID.(PoolClean)` = as.numeric(`ClusterID.(PoolClean)`) ) %>% arrange(`ClusterID.(PoolClean)`)

# Load external cluster annotation information
AnnoInfo <- read.csv(path_to_annotation_info, row.names = 1)

# %%
AnnoInfo
# Out:
#    AnnotationDefinition
# 0  +MPZ
# 1  +EYA1 +ISL1
# 2  +NHLH1
# 3  +MEIS2 +ISL1 +SIX3
# 4  +PCP2 +CA8
# 5  +INA
# 6  +HES1
# 7  +PDGFRA +OLIG1
# 8  +BCAN +TNC
# 9  +TTR +CLIC6
# 10 +HBG1
# 11 +PTPRC
# 12 +AIF1 +HEXB
# 13 +TAGLN
# 14 +RGS5
# 15 +AIF1 +MRC1
# 16 +DCN +COL1A1
# 17 +CLDN5 +FLT1
# 18 +ACTA2 +TAGLN
# 19 +AGRP
# 20 +AVP
# 21 +GNRH1
# 22 +HCRT
# 23 +OXT
# 24 +PMCH
# 25 +POMC
# 26 +TRH
# 27 +DBH +DDC +TH +PNMT
# 28 +CHAT +SLC5A7
# 29 +TH +DDC +SLC6A3
# 30 +DBH +DDC +TH
# 31 +TPH2 +FEV
# 32 +SLC17A7
# 33 +SLC17A6
# 34 +SLC17A8
# 35 +GAD2 -SLC6A5
# 36 +GAD2 +SLC6A5
# 37 +FGF8 +FGF18 +FGF17
# 38 +CRYAB +RSPO2
# 39 +DLX2 +PAX6
# 40 +CORIN
# 41 +PI16
# 42 +DLX2 +NKX2-1
# 43 +EMX1 +LEF1
# 44 +EMX1
# 45 +DLX2 -PAX6 -NKX2-1
# 46 +DLX2 +FOXG1
# 47 +FOXG1
# 48 +TOP2A
# 49 +TOP2A +UNG
# 50 +TOP2A +PLK1
#    AnnotationDescription
# 0  Schwann cell-like (E-SCHWL; +MPZ)
# 1  Otic vesicle of the hindbrain (HB-OTV; +EYA1 +ISL1)
# 2  Neuroblast (NBL; +NHLH1)
# 3  Reticular nucleus of the thalamus (TH-RETN; +MEIS2 +ISL1 +SIX3)
# 4  Purkinje cell (CB-PURK; +PCP2 +CA8)
# 5  Neuron (NEUR; +INA)
# 6  Radial glia (RGL; +HES1)
# 7  Oligodendrocyte precursor (OPC; +PDGFRA +OLIG1)
# 8  Glioblast (GBL; +BCAN +TNC)
# 9  choroid plexus (mesoderm) (M-CHRP; +TTR +CLIC6)
# 10 Erythrocyte (mesoderm) (M-ERY; +HBG1)
# 11 Immune cells (M-IMMUNE; +PTPRC)
# 12 Microglia (mesoderm) (M-MGL; +AIF1 +HEXB)
# 13 Pericytes (mesoderm) (M-PER; +TAGLN)
# 14 Pericytes (mesoderm) (M-PER; +RGS5)
# 15 Perivascular macrophage (mesoderm) (M-PVM; +AIF1 +MRC1)
# 16 Fibroblast (M-FBL; +DCN +COL1A1)
# 17 Endothelial (mesoderm) (M-ENDO; +CLDN5 +FLT1)
# 18 Vascular smooth muscle cell (M-VSMC; +ACTA2 +TAGLN)
# 19 Agouti-related peptide (NP-AGRP; +AGRP)
# 20 Vasopressin (NP-AVP; +AVP)
# 21 Gonadotropin-releasing hormone (NP-GNRH; +GNRH1)
# 22 Orexin-releasing hormone (NP-HCRT; +HCRT)
# 23 Oxytocin (NP-OXT; +OXT)
# 24 Pro-melanin concentrating hormone (NP-PMCH; +PMCH)
# 25 Pro-opiomelanocortin peptide (NP-POMC; +POMC)
# 26 Thyrotropin-releasing hormone (NP-TRH; +TRH)
# 27 Adrenergic (NT-ADR; +DBH +DDC +TH +PNMT)
# 28 Cholinergic (NT-CHOL; +CHAT +SLC5A7)
# 29 Dopaminergic (NT-DA; +TH +DDC +SLC6A3)
# 30 Noradrenergic (NT-NOR; +DBH +DDC +TH)
# 31 Serotonergic (NT-SER; +TPH2 +FEV)
# 32 Glutamatergic 1 (NT-VGLUT1; +SLC17A7)
# 33 Glutamatergic 2 (NT-VGLUT2; +SLC17A6)
# 34 Glutamatergic 3 (NT-VGLUT3; +SLC17A8)
# 35 GABAergic (NT-GABA; +GAD2 -SLC6A5)
# 36 Glycinergic (NT-GLY; +GAD2 +SLC6A5)
# 37 Commissural Plate (O-COP; +FGF8 +FGF18 +FGF17)
# 38 Cortical Hem (O-HEM; +CRYAB +RSPO2)
# 39 Dorsal LGE (SVZ) (P-DLGE; +DLX2 +PAX6)
# 40 Floorplate early (tentative) (P-FP1; +CORIN)
# 41 Floorplate late (tentative) (P-FPL; +PI16)
# 42 MGE and preoptic area (SVZ) (P-MGE-PO; +DLX2 +NKX2-1)
# 43 Radial glia and neurons of the medial pallium (P-PALL-M; +EMX1 +LEF1)
# 44 Radial glia and neurons of the pallium (P-PALL; +EMX1)
# 45 ventral LGE (SVZ) (P-VLGE; +DLX2 -PAX6 -NKX2-1)
# 46 Embryonic telencephalon (P-SUBPALL; +DLX2 +FOXG1)
# 47 Embryonic telencephalon (P-TEL; +FOXG1)
# 48 Cell cycle (S-CC; +TOP2A)
# 49 Cell cycle G1/S phase (S-G1S; +TOP2A +UNG)
# 50 Cell cycle G2/M phase (S-G2M; +TOP2A +PLK1)
#    AnnotationName
# 0  E-SCHWL
# 1  HB-OTV
# 2  NBL
# 3  TH-RETN
# 4  CB-PURK
# 5  NEUR
# 6  RGL
# 7  OPC
# 8  GBL
# 9  M-CHRP
# 10 M-ERY
# 11 M-IMMUNE
# 12 M-MGL
# 13 M-PER
# 14 M-PER
# 15 M-PVM
# 16 M-FBL
# 17 M-ENDO
# 18 M-VSMC
# 19 NP-AGRP
# 20 NP-AVP
# 21 NP-GNRH
# 22 NP-HCRT
# 23 NP-OXT
# 24 NP-PMCH
# 25 NP-POMC
# 26 NP-TRH
# 27 NT-ADR
# 28 NT-CHOL
# 29 NT-DA
# 30 NT-NOR
# 31 NT-SER
# 32 NT-VGLUT1
# 33 NT-VGLUT2
# 34 NT-VGLUT3
# 35 NT-GABA
# 36 NT-GLY
# 37 O-COP
# 38 O-HEM
# 39 P-DLGE
# 40 P-FP1
# 41 P-FPL
# 42 P-MGE-PO
# 43 P-PALL-M
# 44 P-PALL
# 45 P-VLGE
# 46 P-SUBPALL
# 47 P-TEL
# 48 S-CC
# 49 S-G1S
# 50 S-G2M

# %%
# Classify clusters by gene markers (Excitatory/Inhibitory)
lingenes <- list(
    'Excitatory' = c(
        'VGLUT', 'EMX1'
    ),
    'Inhibitory' = c(
        'GAD2', 'DLX'
    )
)

check_cols <- c('PoolEnriched', 'TopLevelEnriched', 'SubsetEnriched')

lin.anno.genes <- st2[,c('ClusterID.(PoolClean)', check_cols)]

paste.coma <- function(...) {paste(..., sep = ',')}

for (lin in names(lingenes)){

    for (col in check_cols){
    
        col.name <- paste(col, lin, sep = '.')
        lin.list <- list()
        
    
        for (g in lingenes[[lin]]){
            
            lin.list[[g]] <- ifelse(grepl(pattern = g, x = lin.anno.genes[,col], fixed = F), g, '')            
            
        }
        

        lin.anno.genes[, col.name] <- do.call(lin.list, what = 'paste.coma') %>%
            gsub(pattern = ',$', fixed=F, replacement = '')%>% 
            gsub(pattern = '^,', fixed=F, replacement = '')
        
        lin.anno.genes[lin.anno.genes[, col.name] == '', col.name] <- NA
        lin.anno.genes[!is.na(lin.anno.genes[, col.name]), col.name] <- paste(
            col, 
            lin.anno.genes[!is.na(lin.anno.genes[, col.name]), col.name],
            sep = ':')
        
    }
}

lin.anno.genes$gene.anno.exc <- apply(lin.anno.genes[,grepl(colnames(lin.anno.genes), pattern = 'Excitatory')], 
                                  MARGIN = 1, FUN = function(x) {
    if (all(is.na(x))){NA}else{paste0('EXCIT>', paste(x[!is.na(x)], collapse = ';'))}})

lin.anno.genes$gene.anno.inh <- apply(lin.anno.genes[,grepl(colnames(lin.anno.genes), pattern = 'Inhibitory')], 
                                  MARGIN = 1, FUN = function(x) {
    if (all(is.na(x))){NA}else{paste0('INHIB>', paste(x[!is.na(x)], collapse = ';'))}})

lin.anno.genes$gene.anno <- apply(lin.anno.genes[,c('gene.anno.exc','gene.anno.inh')], 
                                  MARGIN = 1, FUN = function(x) {
    if (all(is.na(x))){NA}else{paste(x[!is.na(x)], collapse = ' || ')}})

# apply(lin.anno.genes[,-(1:4)], MARGIN = 2, FUN = unique)

# %%
# Classify clusters by lineage annotations (Excitatory/Inhibitory)
lineages <- list(
    'Excitatory' = c(
        'NT-VGLUT1', 'NT-VGLUT2', 'NT-VGLUT3', # GLUT
        'P-PALL-M', 'P-PALL' # EMX1
    ),
    'Inhibitory' = c(
        'NT-GABA', # GAD2
        'P-DLGE', 'P-VLGE', 'P-SUBPALL', # DLX2
        'P-MGE-PO' # GAD2
    )
)

lin.annos <- st2[,c('ClusterID.(PoolClean)','NCells','AutoClass','Class','Subclass')]

for (lin in names(lineages)){
    for (ct in lineages[[lin]]){
        
        coincident <- grepl(pattern = ct, x = st2$AutoAnnotation,fixed = T)
        
        lin.annos <- cbind(lin.annos, ifelse(coincident, lin, NA))
        colnames(lin.annos)[ncol(lin.annos)] <- paste(lin, ct, sep='.')
        
    }
}

lin.annos$annot <- apply(lin.annos[,-(1:3)], 1, function(x){
    paste(unique(x[!is.na(x)]), collapse='::')
})

# %%
merge(lin.annos[,c(1,ncol(lin.annos))], lin.anno.genes[,-(2:4)], by = 'ClusterID.(PoolClean)') %>%
merge(y = st2, by = 'ClusterID.(PoolClean)') -> annotation.table

# %%
# Check self-consistency within lineage and gene annotations
annotation.table$annot.selfconsistent <- !(grepl('Inhibitory', x = annotation.table$annot, fixed=T)&grepl('Excitatory', x = annotation.table$annot, fixed=T))

annotation.table$geneannot.selfconsistent <- !(grepl('INHIB>', x = annotation.table$gene.anno, fixed=T)&grepl('EXCIT>', x = annotation.table$gene.anno, fixed=T))


# Check consistency between lineage and gene annotations
annotation.table$annot.betweenconsistent <- !(grepl('Inhibitory', x = annotation.table$annot, fixed=T)&grepl('EXCIT>', x = annotation.table$gene.anno, fixed=T)) & !(grepl('Excitatory', x = annotation.table$annot, fixed=T)&grepl('INHIB>', x = annotation.table$gene.anno, fixed=T))

# Define overall consistency based on self and between-column checks
annotation.table$consistent.all <- annotation.table$annot.betweenconsistent & annotation.table$annot.selfconsistent & annotation.table$geneannot.selfconsistent

# %%
all.cols <- unique(c(colnames(st2), colnames(lin.annos),colnames(lin.anno.genes)))
all.cols <- all.cols[all.cols %in% colnames(annotation.table)]
first.cols <- c('PoolOrder','ClusterID.(PoolClean)','NCells','AutoClass','Class','Subclass', 'consistent.all', 'annot', 'gene.anno', 'annot.selfconsistent', 'geneannot.selfconsistent', 'annot.betweenconsistent')
first.cols <- first.cols[first.cols%in%colnames(annotation.table)]
all.cols <- all.cols[!all.cols %in% first.cols]

annotation.table <- annotation.table[, c(first.cols, all.cols)]

# %%
openxlsx::write.xlsx(annotation.table, './cluster_lineage_annotation.xlsx')

# %%
# check inconsistencies
subset(annotation.table, !consistent.all)
# Out:
#     PoolOrder ClusterID.(PoolClean) NCells AutoClass   Class
# 65  459        64                    554   Radial glia Radial glia
# 156 381       155                   7013   Radial glia Radial glia
# 159 378       158                   1171   Radial glia Radial glia
# 168 374       167                   2144   Radial glia Radial glia
# 172 384       171                   3988   Glioblast   Glioblast
# 173 385       172                    375   Glioblast   Radial glia
# 206 428       205                   3320   Radial glia Neuron
# 296 357       295                   5479   Neuroblast  Neuroblast
# 299 361       298                    664   Radial glia Neuroblast
# 325 331       324                   1051   Neuron      Neuron
# 336 297       335                    623   Neuroblast  Neuron
# 337 298       336                   1100   Neuron      Neuron
# 338 299       337                    582   Neuron      Neuron
# 340 258       339                   1678   Neuron      Neuron
# 359 239       358                    452   Neuron      Neuronal IPC
# 365 228       364                   5260   Radial glia Neuron
# 376 214       375                   5171   Neuroblast  Neuron
# 379 220       378                    506   Neuron      Neuron
# 403 147       402                    550   Neuron      Neuron
# 501 269       500                    716   Neuron      Neuron
# 502 268       501                   1402   Neuroblast  Neuron
# 503 267       502                   1785   Neuroblast  Neuron
# 508 263       507                   5574   Neuron      Neuron
# 516 106       515                   3873   Neuron      Neuron
# 565  29       564                   2312   Neuron      Neuron
#     Subclass     consistent.all annot
# 65  Radial glia  FALSE          Radial glia::Excitatory::Inhibitory
# 156 Radial glia  FALSE          Radial glia::Excitatory::Inhibitory
# 159 Radial glia  FALSE          Radial glia::Excitatory
# 168 Radial glia  FALSE          Radial glia::Excitatory::Inhibitory
# 172 Glioblast    FALSE          Glioblast::Excitatory
# 173 Radial glia  FALSE          Radial glia::Excitatory
# 206 Neuron       FALSE          Neuron::Excitatory
# 296 Neuroblast   FALSE          Neuroblast::Excitatory::Inhibitory
# 299 Neuroblast   FALSE          Neuroblast::Excitatory
# 325 Neuron       FALSE          Neuron::Excitatory
# 336 Neuron       FALSE          Neuron::Excitatory::Inhibitory
# 337 Neuron       FALSE          Neuron::Excitatory::Inhibitory
# 338 Neuron       FALSE          Neuron::Excitatory
# 340 Neuron       FALSE          Neuron::Excitatory
# 359 Neuronal IPC FALSE          Neuronal IPC::Excitatory::Inhibitory
# 365 Neuron       FALSE          Neuron::Excitatory::Inhibitory
# 376 Neuron       FALSE          Neuron::Excitatory::Inhibitory
# 379 Neuron       FALSE          Neuron::Inhibitory
# 403 Neuron       FALSE          Neuron::Excitatory
# 501 Neuron       FALSE          Neuron::Excitatory
# 502 Neuron       FALSE          Neuron::Excitatory
# 503 Neuron       FALSE          Neuron::Excitatory
# 508 Neuron       FALSE          Neuron::Excitatory
# 516 Neuron       FALSE          Neuron::Excitatory::Inhibitory
# 565 Neuron       FALSE          Neuron::Excitatory
#     gene.anno                                        annot.selfconsistent ⋯
# 65  NA                                               FALSE                ⋯
# 156 NA                                               FALSE                ⋯
# 159 INHIB>PoolEnriched:DLX;SubsetEnriched:GAD2,DLX    TRUE                ⋯
# 168 NA                                               FALSE                ⋯
# 172 INHIB>SubsetEnriched:DLX                          TRUE                ⋯
# 173 INHIB>SubsetEnriched:GAD2,DLX                     TRUE                ⋯
# 206 INHIB>PoolEnriched:GAD2,DLX;TopLevelEnriched:DLX  TRUE                ⋯
# 296 NA                                               FALSE                ⋯
# 299 INHIB>SubsetEnriched:GAD2,DLX                     TRUE                ⋯
# 325 INHIB>SubsetEnriched:GAD2,DLX                     TRUE                ⋯
# 336 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX      FALSE                ⋯
# 337 INHIB>TopLevelEnriched:DLX                       FALSE                ⋯
# 338 INHIB>TopLevelEnriched:DLX                        TRUE                ⋯
# 340 INHIB>TopLevelEnriched:DLX                        TRUE                ⋯
# 359 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX      FALSE                ⋯
# 365 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX      FALSE                ⋯
# 376 NA                                               FALSE                ⋯
# 379 EXCIT>SubsetEnriched:EMX1                         TRUE                ⋯
# 403 INHIB>SubsetEnriched:DLX                          TRUE                ⋯
# 501 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX       TRUE                ⋯
# 502 INHIB>TopLevelEnriched:DLX                        TRUE                ⋯
# 503 INHIB>SubsetEnriched:DLX                          TRUE                ⋯
# 508 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX       TRUE                ⋯
# 516 NA                                               FALSE                ⋯
# 565 INHIB>SubsetEnriched:GAD2                         TRUE                ⋯
#     Location.D-V.(Week5) Germinal.zone.(Week5) PoolEnriched.Excitatory
# 65  NA                   NA                    NA
# 156 NA                   NA                    NA
# 159 NA                   NA                    NA
# 168 NA                   NA                    NA
# 172 NA                   NA                    NA
# 173 NA                   NA                    NA
# 206 NA                   NA                    NA
# 296 NA                   NA                    NA
# 299 NA                   NA                    NA
# 325 NA                   NA                    NA
# 336 NA                   NA                    NA
# 337 NA                   NA                    NA
# 338 NA                   NA                    NA
# 340 NA                   NA                    NA
# 359 NA                   NA                    NA
# 365 NA                   NA                    NA
# 376 NA                   NA                    NA
# 379 NA                   NA                    NA
# 403 NA                   NA                    NA
# 501 NA                   NA                    NA
# 502 NA                   NA                    NA
# 503 NA                   NA                    NA
# 508 Ventral              MZ                    NA
# 516 NA                   NA                    NA
# 565 Ventral              MZ                    NA
#     TopLevelEnriched.Excitatory SubsetEnriched.Excitatory
# 65  NA                          NA
# 156 NA                          NA
# 159 NA                          NA
# 168 NA                          NA
# 172 NA                          NA
# 173 NA                          NA
# 206 NA                          NA
# 296 NA                          NA
# 299 NA                          NA
# 325 NA                          NA
# 336 NA                          NA
# 337 NA                          NA
# 338 NA                          NA
# 340 NA                          NA
# 359 NA                          NA
# 365 NA                          NA
# 376 NA                          NA
# 379 NA                          SubsetEnriched:EMX1
# 403 NA                          NA
# 501 NA                          NA
# 502 NA                          NA
# 503 NA                          NA
# 508 NA                          NA
# 516 NA                          NA
# 565 NA                          NA
#     PoolEnriched.Inhibitory TopLevelEnriched.Inhibitory
# 65  NA                      NA
# 156 NA                      NA
# 159 PoolEnriched:DLX        NA
# 168 NA                      NA
# 172 NA                      NA
# 173 NA                      NA
# 206 PoolEnriched:GAD2,DLX   TopLevelEnriched:DLX
# 296 NA                      NA
# 299 NA                      NA
# 325 NA                      NA
# 336 PoolEnriched:DLX        TopLevelEnriched:DLX
# 337 NA                      TopLevelEnriched:DLX
# 338 NA                      TopLevelEnriched:DLX
# 340 NA                      TopLevelEnriched:DLX
# 359 PoolEnriched:DLX        TopLevelEnriched:DLX
# 365 PoolEnriched:DLX        TopLevelEnriched:DLX
# 376 NA                      NA
# 379 NA                      NA
# 403 NA                      NA
# 501 PoolEnriched:DLX        TopLevelEnriched:DLX
# 502 NA                      TopLevelEnriched:DLX
# 503 NA                      NA
# 508 PoolEnriched:DLX        TopLevelEnriched:DLX
# 516 NA                      NA
# 565 NA                      NA
#     SubsetEnriched.Inhibitory gene.anno.exc
# 65  NA                        NA
# 156 NA                        NA
# 159 SubsetEnriched:GAD2,DLX   NA
# 168 NA                        NA
# 172 SubsetEnriched:DLX        NA
# 173 SubsetEnriched:GAD2,DLX   NA
# 206 NA                        NA
# 296 NA                        NA
# 299 SubsetEnriched:GAD2,DLX   NA
# 325 SubsetEnriched:GAD2,DLX   NA
# 336 NA                        NA
# 337 NA                        NA
# 338 NA                        NA
# 340 NA                        NA
# 359 NA                        NA
# 365 NA                        NA
# 376 NA                        NA
# 379 NA                        EXCIT>SubsetEnriched:EMX1
# 403 SubsetEnriched:DLX        NA
# 501 NA                        NA
# 502 NA                        NA
# 503 SubsetEnriched:DLX        NA
# 508 NA                        NA
# 516 NA                        NA
# 565 SubsetEnriched:GAD2       NA
#     gene.anno.inh
# 65  NA
# 156 NA
# 159 INHIB>PoolEnriched:DLX;SubsetEnriched:GAD2,DLX
# 168 NA
# 172 INHIB>SubsetEnriched:DLX
# 173 INHIB>SubsetEnriched:GAD2,DLX
# 206 INHIB>PoolEnriched:GAD2,DLX;TopLevelEnriched:DLX
# 296 NA
# 299 INHIB>SubsetEnriched:GAD2,DLX
# 325 INHIB>SubsetEnriched:GAD2,DLX
# 336 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX
# 337 INHIB>TopLevelEnriched:DLX
# 338 INHIB>TopLevelEnriched:DLX
# 340 INHIB>TopLevelEnriched:DLX
# 359 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX
# 365 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX
# 376 NA
# 379 NA
# 403 INHIB>SubsetEnriched:DLX
# 501 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX
# 502 INHIB>TopLevelEnriched:DLX
# 503 INHIB>SubsetEnriched:DLX
# 508 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX
# 516 NA
# 565 INHIB>SubsetEnriched:GAD2

# %% [markdown]
# # Part 2: Solve inconsistencies manually

# %%
# res: Dataframe holding the manually reviewed and commented annotations.
res <- openxlsx::read.xlsx('./cluster_lineage_annotation.commented.xlsx')
head(res)
# Out:
#   PoolOrder ClusterID.(PoolClean) NCells AutoClass   Class      Subclass
# 1 361       298                    664   Radial glia Neuroblast Neuroblast
# 2 331       324                   1051   Neuron      Neuron     Neuron
# 3 297       335                    623   Neuroblast  Neuron     Neuron
# 4  29       564                   2312   Neuron      Neuron     Neuron
# 5 147       402                    550   Neuron      Neuron     Neuron
# 6 269       500                    716   Neuron      Neuron     Neuron
#   Diagnotic consistent.all comment.anno       annot                          ⋯
# 1 ExN       FALSE          NT-GLUT + GAD2,DLX Neuroblast::Excitatory         ⋯
# 2 ExN       FALSE          NT-GLUT + GAD2,DLX Neuron::Excitatory             ⋯
# 3 DUDOSO    FALSE          NT-GLUT + GAD2,DLX Neuron::Excitatory::Inhibitory ⋯
# 4 DUDOSO    FALSE          NT-GLUT + GAD2     Neuron::Excitatory             ⋯
# 5 DUDOSO    FALSE          NT-GLUT + DLX      Neuron::Excitatory             ⋯
# 6 DUDOSO    FALSE          NT-GLUT + DLX      Neuron::Excitatory             ⋯
#   Location.D-V.(Week5) Germinal.zone.(Week5) PoolEnriched.Excitatory
# 1 NA                   NA                    NA
# 2 NA                   NA                    NA
# 3 NA                   NA                    NA
# 4 Ventral              MZ                    NA
# 5 NA                   NA                    NA
# 6 NA                   NA                    NA
#   TopLevelEnriched.Excitatory SubsetEnriched.Excitatory PoolEnriched.Inhibitory
# 1 NA                          NA                        NA
# 2 NA                          NA                        NA
# 3 NA                          NA                        PoolEnriched:DLX
# 4 NA                          NA                        NA
# 5 NA                          NA                        NA
# 6 NA                          NA                        PoolEnriched:DLX
#   TopLevelEnriched.Inhibitory SubsetEnriched.Inhibitory gene.anno.exc
# 1 NA                          SubsetEnriched:GAD2,DLX   NA
# 2 NA                          SubsetEnriched:GAD2,DLX   NA
# 3 TopLevelEnriched:DLX        NA                        NA
# 4 NA                          SubsetEnriched:GAD2       NA
# 5 NA                          SubsetEnriched:DLX        NA
# 6 TopLevelEnriched:DLX        NA                        NA
#   gene.anno.inh
# 1 INHIB>SubsetEnriched:GAD2,DLX
# 2 INHIB>SubsetEnriched:GAD2,DLX
# 3 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX
# 4 INHIB>SubsetEnriched:GAD2
# 5 INHIB>SubsetEnriched:DLX
# 6 INHIB>PoolEnriched:DLX;TopLevelEnriched:DLX

# %%
res <- res[,c('ClusterID.(PoolClean)', 'Class', 'Subclass', 'Diagnotic', 'annot', 'gene.anno', 'consistent.all')]

# %%
# Combine 'Class' and 'Subclass' columns into 'ClassSubclass'
res$ClassSubclass <- apply(res[,c('Class', 'Subclass')], 1, function(x){paste(unique(x), collapse = ':')})

# %%
res$discarded <- (res$Diagnotic == 'DUDOSO') & !is.na(res$Diagnotic)

# %%
res$do.InEx <- res$Class %in% c('Neuroblast', 'Neuron', 'Neuronal IPC')
res$InEx <- NA

# %%
# Resolve inconsistent cases using 'Diagnotic' column
mask <- (!res$consistent.all)&(!res$discarded)&res$do.InEx
res[mask,'InEx'] <- res[mask,'Diagnotic']
res$InEx <- ifelse(is.na(res$InEx), NA, sapply(res$InEx, substr, start = 1, stop = 2))
# Assign In/Ex based on consistent 'annot' column
mask <- (res$consistent.all)&(!res$discarded)&res$do.InEx
res[mask,'InEx'] <- ifelse(grepl(res[mask,'annot'], pattern = 'Inhibitory', fixed=T), 'In', 'Ex')
# Assign remaining In/Ex based on 'gene.anno' column for consistent cases
mask <- (res$consistent.all)&(!res$discarded)&res$do.InEx&is.na(res$InEx)
res[mask,'InEx'] <- ifelse(grepl(res[mask,'gene.anno'], pattern = 'INHIB', fixed=T), 'In', 'Ex')
# Out:
# [1] 0
# [1] 0
# [1] 0

# %%
short.names <- c(
    'COPs (premyelinating)' = 'COPs',
    'Endothelial' = 'Endo',
    'Erythrocyte' = 'Eryt',
    'Fibroblast' = 'Fibr',
    'Glioblast' = 'GlioBl',
    'Immune' = 'Imm',
    'Neuroblast' = 'NeuBl',
    'Neuron' = 'Neu',
    'Neuronal IPC' = 'NeuIPC',
    'OPC' = 'OPC',
    'Pericytes' = 'Peri',
    'Placodes' = 'Plac',
    'Radial glia' = 'RGC',
    'Schwann' = 'Schwann',
    'VSMC' = 'VSMC')

# %%
table(res[,c('do.InEx','InEx')])
table(res[,c('Subclass','InEx')])


# Note: Using 'Subclass' for final naming convention
# Generate long name identifier (In/Ex + Class:Subclass)
res$LongName <- ifelse(
    res$discarded, NA, apply(
        res[,c('InEx', 'ClassSubclass')], 1, 
        function(x){
            paste(x[!is.na(x)], collapse = '')}))
    
# Generate short name identifier (In/Ex + Abbreviated Subclass)
res$ShortName <- ifelse(
    res$discarded, NA, apply(
        res[,c('InEx', 'Subclass')], 1, 
        function(x){
            x[2] <- short.names[x[2]]
            paste(x[!is.na(x)], collapse = '')}))
# Out:
#        InEx
# do.InEx  Ex  In
#   FALSE   0   0
#   TRUE  213 133
#                        InEx
# Subclass                 Ex  In
#   COPs (premyelinating)   0   0
#   Endothelial             0   0
#   Erythrocyte             0   0
#   Fibroblast              0   0
#   Glioblast               0   0
#   Immune                  0   0
#   Neuroblast             95   9
#   Neuron                 99 111
#   Neuronal IPC           19  13
#   OPC                     0   0
#   Pericytes               0   0
#   Placodes                0   0
#   Radial glia             0   0
#   Schwann                 0   0
#   VSMC                    0   0

# %%
openxlsx::write.xlsx(res, './cluster_lineage_annotation.summary.xlsx')
